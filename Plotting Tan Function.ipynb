# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
     return np.tan(np.radians(x))

# %%
x = np.arange(0,721)

# %%
plt.plot(x, func(x))

xlabel('Degrees')
ylabel('Tan function')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13328\2463601279.py in <module>
#       1 plt.plot(x, func(x))
#       2
# ----> 3 xlabel('Degrees')
#       4 ylabel('Tan function')
#
# NameError: name 'xlabel' is not defined
