# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def func(x):
    return np.sin(np.radians(x))

# %%
x = np.arange(0,721)

# %%
plt.plot(x, func(x))

plt.xlabel("Degrees")
plt.ylabel("Sine Function")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10896\823697681.py in <module>
#       2
#       3 plt.xlabel("Degrees")
# ----> 4 plt.ylabel("Sine Function")
#
# TypeError: 'numpy.ndarray' object is not callable
